# %% [markdown]
# ## Preparing Data

# %%
import twder
import pandas as pd
from datetime import datetime

# in the same trading day, p6m and p1d are identical
def FE_form(df):
    df.columns = ['date', 'cashbuy', 'cashsell', 'buy', 'sell']
    df['date'] = pd.to_datetime(df['date'])
    
    return pd.concat([df['date'], df['sell']], 1)

def past6mon(currency):
    temp = pd.DataFrame(twder.past_six_month(currency))
    df = FE_form(temp)
    
    return df

def past1day(currency):
    temp = pd.DataFrame(twder.past_day(currency))
    df = FE_form(temp)
    
    return df

# %% [markdown]
# 1. get all the FE money amount
# 1. get taiwan stock changes
# 1. get S&P, SOX, NASDAQ

# %%
p6m = past6mon('USD') 
p6m.head(5)
# Out:
#         date    sell
# 0 2019-03-22  30.845
# 1 2019-03-21   30.86
# 2 2019-03-20   30.88
# 3 2019-03-19   30.88
# 4 2019-03-18   30.88

# %%
p1d = past1day('USD') 
p1d.head(5)
# Out:
#                  date    sell
# 0 2019-03-22 09:01:22   30.85
# 1 2019-03-22 09:02:54  30.855
# 2 2019-03-22 09:07:03   30.86
# 3 2019-03-22 09:12:47  30.865
# 4 2019-03-22 09:17:06   30.87

# %% [markdown]
# https://www.fxcm.com/fxcmpy/00_quick_start.html#Package-Installation
# fxcmpy – Algorithmic Trading with FXCM

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')
% matplotlib inline

# %%
plt.figure(figsize=(12, 8))
plt.plot(p6m['date'], p6m['sell'], 'g')

# %%
import torch

# %%
import torch.nn as nn
import torch.nn.functional as F
from torch import optim
from torch.jit import script, trace
